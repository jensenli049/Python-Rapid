# %% [markdown]
# ## 1. Install Dependencies

# %%
pip install -r requirements.txt
# Out:
# Obtaining mmrotate from git+https://github.com/open-mmlab/mmrotate.git@04405ab0f0f0c580cc909df15a162de65a9b668a#egg=mmrotate (from -r requirements.txt (line 97))
#   Cloning https://github.com/open-mmlab/mmrotate.git (to revision 04405ab0f0f0c580cc909df15a162de65a9b668a) to c:\users\jense\documents\python-rapid\src\mmrotate
#   Resolved https://github.com/open-mmlab/mmrotate.git to commit 04405ab0f0f0c580cc909df15a162de65a9b668a
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: absl-py==1.4.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: addict==2.4.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: alabaster==0.7.13 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 3)) (0.7.13)
# Requirement already satisfied: albumentations==1.3.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: anyio in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 7)) (20.1.0)
# Requirement already satisfied: asttokens in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 8)) (2.0.5)
# Requirement already satisfied: attrs in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 9)) (22.1.0)
# Requirement already satisfied: Babel==2.12.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 10)) (2.12.1)
# Requirement already satisfied: backcall in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 12)) (4.11.1)
# Requirement already satisfied: bleach in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 13)) (4.1.0)
# Requirement already satisfied: boto3==1.26.150 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 14)) (1.26.150)
# Requirement already satisfied: botocore==1.29.150 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 15)) (1.29.150)
# Requirement already satisfied: Brotli==1.0.9 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 16)) (1.0.9)
# Requirement already satisfied: brotlipy==0.7.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: build==0.10.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 18)) (0.10.0)
# Requirement already satisfied: cachetools==4.2.4 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 19)) (4.2.4)
# Requirement already satisfied: certifi in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 20)) (2023.5.7)
# Requirement already satisfied: cffi in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 21)) (1.15.1)
# Requirement already satisfied: charset-normalizer==3.1.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 22)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 23)) (8.1.3)
# Requirement already satisfied: colorama in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 24)) (0.4.6)
# Requirement already satisfied: coloredlogs==15.0.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 25)) (15.0.1)
# Requirement already satisfied: comm in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 26)) (0.1.2)
# Requirement already satisfied: contourpy==1.0.6 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 27)) (1.0.6)
# Requirement already satisfied: coverage==5.3.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 28)) (5.3.1)
# Requirement already satisfied: cryptography in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 29)) (38.0.4)
# Requirement already satisfied: cycler==0.11.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 30)) (0.11.0)
# Requirement already satisfied: Cython==0.29.35 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 31)) (0.29.35)
# Requirement already satisfied: debugpy in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 32)) (1.5.1)
# Requirement already satisfied: decorator in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 33)) (5.1.1)
# Requirement already satisfied: defusedxml in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 34)) (0.7.1)
# Requirement already satisfied: Deprecated==1.2.14 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 35)) (1.2.14)
# Requirement already satisfied: docutils==0.17.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 36)) (0.17.1)
# Requirement already satisfied: e2cnn==0.2.3 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 37)) (0.2.3)
# Requirement already satisfied: einops==0.3.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 38)) (0.3.2)
# Requirement already satisfied: entrypoints in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 39)) (0.4)
# Requirement already satisfied: executing in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 40)) (0.8.3)
# Requirement already satisfied: fastjsonschema in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 41)) (2.16.2)
# Requirement already satisfied: flatbuffers==23.5.26 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 42)) (23.5.26)
# Requirement already satisfied: fonttools==4.40.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 43)) (4.40.0)
# Requirement already satisfied: future==0.18.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 44)) (0.18.3)
# Requirement already satisfied: google-auth==2.19.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 45)) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 46)) (1.0.0)
# Requirement already satisfied: grpcio==1.54.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 47)) (1.54.2)
# Requirement already satisfied: humanfriendly==10.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 48)) (10.0)
# Requirement already satisfied: hydra-core==1.3.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 49)) (1.3.2)
# Requirement already satisfied: idna==3.4 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 50)) (3.4)
# Requirement already satisfied: imageio==2.31.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 51)) (2.31.1)
# Requirement already satisfied: imagesize==1.4.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 52)) (1.4.1)
# Requirement already satisfied: importlib-metadata==6.6.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 53)) (6.6.0)
# Requirement already satisfied: importlib-resources==5.12.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 54)) (5.12.0)
# Requirement already satisfied: imutils==0.5.4 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 55)) (0.5.4)
# Requirement already satisfied: ipykernel in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 56)) (6.19.2)
# Requirement already satisfied: ipython in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 57)) (8.8.0)
# Requirement already satisfied: ipython-genutils in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 58)) (0.2.0)
# Requirement already satisfied: ipywidgets in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 59)) (7.6.5)
# Requirement already satisfied: jedi in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 60)) (0.18.1)
# Requirement already satisfied: Jinja2 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 61)) (3.1.2)
# Requirement already satisfied: jmespath==1.0.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 62)) (1.0.1)
# Requirement already satisfied: joblib==1.2.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 63)) (1.2.0)
# Requirement already satisfied: json-tricks==3.16.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 64)) (3.16.1)
# Requirement already satisfied: json5 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 65)) (0.9.6)
# Requirement already satisfied: jsonschema in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 66)) (4.16.0)
# Requirement already satisfied: jupyter in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 67)) (1.0.0)
# Requirement already satisfied: jupyter-console in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 68)) (6.4.4)
# Requirement already satisfied: jupyter-server in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 69)) (1.23.4)
# Requirement already satisfied: jupyter_client in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 70)) (7.4.8)
# Requirement already satisfied: jupyter_core in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 71)) (5.1.1)
# Requirement already satisfied: jupyterlab in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 72)) (3.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 73)) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 74)) (1.0.0)
# Requirement already satisfied: jupyterlab_server in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 75)) (2.16.5)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 76)) (1.1.2)
# Requirement already satisfied: keras-resnet==0.2.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 77)) (0.2.0)
# Requirement already satisfied: keras-retinanet in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 78)) (1.0.0)
# Requirement already satisfied: keyboard==0.13.5 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 79)) (0.13.5)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 80)) (1.4.4)
# Requirement already satisfied: lazy_loader==0.2 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 81)) (0.2)
# Requirement already satisfied: lxml in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 82)) (4.9.1)
# Requirement already satisfied: Markdown==3.4.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 83)) (3.4.3)
# Requirement already satisfied: markdown-it-py==2.2.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 84)) (2.2.0)
# Requirement already satisfied: MarkupSafe==2.1.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 85)) (2.1.3)
# Requirement already satisfied: matplotlib==3.7.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 86)) (3.7.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 87)) (0.1.6)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 88)) (0.1.2)
# Requirement already satisfied: mistune==0.8.4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 89)) (0.8.4)
# Requirement already satisfied: mkl-fft==1.3.6 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 90)) (1.3.6)
# Requirement already satisfied: mkl-random in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 91)) (1.2.2)
# Requirement already satisfied: mkl-service==2.4.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 92)) (2.4.0)
# Requirement already satisfied: mmcv==2.0.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 93)) (2.0.0)
# Requirement already satisfied: mmcv-full==1.7.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 94)) (1.7.1)
# Requirement already satisfied: mmdet==2.28.2 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 95)) (2.28.2)
# Requirement already satisfied: mmengine==0.7.4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 96)) (0.7.4)
# Requirement already satisfied: model-index==0.1.11 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 98)) (0.1.11)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 99)) (1.3.0)
# Requirement already satisfied: mutagen==1.46.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 100)) (1.46.0)
# Requirement already satisfied: nbclassic in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 101)) (0.4.8)
# Requirement already satisfied: nbclient in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 102)) (0.5.13)
# Requirement already satisfied: nbconvert in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 103)) (6.5.4)
# Requirement already satisfied: nbformat in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 104)) (5.7.0)
# Requirement already satisfied: nest-asyncio in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 105)) (1.5.6)
# Requirement already satisfied: networkx==3.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 106)) (3.1)
# Requirement already satisfied: ninja==1.11.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 107)) (1.11.1)
# Requirement already satisfied: notebook in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 108)) (6.5.2)
# Requirement already satisfied: notebook_shim in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 109)) (0.2.2)
# Requirement already satisfied: numpy==1.23.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 110)) (1.23.0)
# Requirement already satisfied: oauthlib==3.2.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 111)) (3.2.2)
# Requirement already satisfied: omegaconf==2.3.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 112)) (2.3.0)
# Requirement already satisfied: onnx==1.13.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 113)) (1.13.0)
# Requirement already satisfied: onnx-simplifier==0.4.31 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 114)) (0.4.31)
# Requirement already satisfied: onnxruntime==1.13.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 115)) (1.13.1)
# Requirement already satisfied: opencv-python==4.8.0.74 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 116)) (4.8.0.74)
# Requirement already satisfied: openmim==0.3.7 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 117)) (0.3.7)
# Requirement already satisfied: ordered-set==4.1.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 118)) (4.1.0)
# Requirement already satisfied: packaging in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 119)) (22.0)
# Requirement already satisfied: pafy==0.5.5 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 120)) (0.5.5)
# Requirement already satisfied: pandas==2.0.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 121)) (2.0.3)
# Requirement already satisfied: pandocfilters in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 122)) (1.5.0)
# Requirement already satisfied: parso in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 123)) (0.8.3)
# Requirement already satisfied: pickleshare in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 124)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 125)) (9.5.0)
# Requirement already satisfied: pip-tools==6.13.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 126)) (6.13.0)
# Requirement already satisfied: pkgutil_resolve_name in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 127)) (1.3.10)
# Requirement already satisfied: platformdirs==3.5.3 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 128)) (3.5.3)
# Requirement already satisfied: ply==3.11 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 129)) (3.11)
# Requirement already satisfied: prettytable==3.8.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 130)) (3.8.0)
# Requirement already satisfied: progressbar2==3.55.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 131)) (3.55.0)
# Requirement already satisfied: prometheus-client in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 132)) (0.14.1)
# Requirement already satisfied: prompt-toolkit in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 133)) (3.0.20)
# Requirement already satisfied: protobuf==3.20.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 134)) (3.20.3)
# Requirement already satisfied: psutil==5.9.5 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 135)) (5.9.5)
# Requirement already satisfied: pure-eval in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 136)) (0.2.2)
# Requirement already satisfied: pyasn1==0.5.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 137)) (0.5.0)
# Requirement already satisfied: pyasn1-modules==0.3.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 138)) (0.3.0)
# Requirement already satisfied: pycocotools==2.0.4 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 139)) (2.0.4)
# Requirement already satisfied: pycparser in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 140)) (2.21)
# Requirement already satisfied: pycryptodomex==3.18.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 141)) (3.18.0)
# Requirement already satisfied: pyDeprecate==0.3.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 142)) (0.3.2)
# Requirement already satisfied: Pygments==2.15.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 143)) (2.15.1)
# Requirement already satisfied: pyOpenSSL in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 144)) (22.0.0)
# Requirement already satisfied: pyparsing==2.4.5 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 145)) (2.4.5)
# Requirement already satisfied: pyproject_hooks==1.0.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 146)) (1.0.0)
# Requirement already satisfied: PyQt5==5.15.7 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 147)) (5.15.7)
# Requirement already satisfied: PyQt5-sip in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 148)) (12.11.0)
# Requirement already satisfied: pyreadline3==3.4.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 149)) (3.4.1)
# Requirement already satisfied: pyrsistent in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 150)) (0.18.0)
# Requirement already satisfied: PySocks in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 151)) (1.7.1)
# Requirement already satisfied: python-dateutil in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 152)) (2.8.2)
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 153)) (1.0.0)
# Requirement already satisfied: python-utils==2.5.6 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 154)) (2.5.6)
# Requirement already satisfied: pytz==2022.7 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 155)) (2022.7)
# Requirement already satisfied: PyWavelets==1.4.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 156)) (1.4.1)
# Requirement already satisfied: pywin32==305.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 157)) (305.1)
# Requirement already satisfied: pywinpty in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 158)) (2.0.2)
# Requirement already satisfied: PyYAML==6.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 159)) (6.0)
# Requirement already satisfied: pyzmq in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 160)) (23.2.0)
# Requirement already satisfied: qtconsole in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 161)) (5.4.0)
# Requirement already satisfied: QtPy in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 162)) (2.2.0)
# Requirement already satisfied: qudida==0.0.4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 163)) (0.0.4)
# Requirement already satisfied: rapidfuzz==3.1.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 164)) (3.1.1)
# Requirement already satisfied: regex==2023.6.3 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 165)) (2023.6.3)
# Requirement already satisfied: requests==2.31.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 166)) (2.31.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 167)) (1.3.1)
# Requirement already satisfied: rich==13.4.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 168)) (13.4.1)
# Requirement already satisfied: roboflow==0.1.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 169)) (0.1.1)
# Requirement already satisfied: rsa==4.9 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 170)) (4.9)
# Requirement already satisfied: s3transfer==0.6.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 171)) (0.6.1)
# Requirement already satisfied: scikit-image==0.21.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 172)) (0.21.0)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 173)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 174)) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 175)) (0.12.2)
# Requirement already satisfied: Send2Trash in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 176)) (1.8.0)
# Requirement already satisfied: shapely==2.0.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 177)) (2.0.1)
# Requirement already satisfied: sip in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 178)) (6.6.2)
# Requirement already satisfied: six in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 179)) (1.16.0)
# Requirement already satisfied: sniffio in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 180)) (1.2.0)
# Requirement already satisfied: snowballstemmer==2.2.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 181)) (2.2.0)
# Requirement already satisfied: soupsieve in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 182)) (2.3.2.post1)
# Requirement already satisfied: Sphinx==4.0.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 183)) (4.0.3)
# Requirement already satisfied: sphinx-rtd-theme==1.2.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 184)) (1.2.2)
# Requirement already satisfied: sphinxcontrib-applehelp==1.0.4 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 185)) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp==1.0.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 186)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-htmlhelp==2.0.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 187)) (2.0.1)
# Requirement already satisfied: sphinxcontrib-jquery==4.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 188)) (4.1)
# Requirement already satisfied: sphinxcontrib-jsmath==1.0.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 189)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp==1.0.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 190)) (1.0.3)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.5 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 191)) (1.1.5)
# Requirement already satisfied: stack-data in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 192)) (0.2.0)
# Requirement already satisfied: stringcase==1.2.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 193)) (1.2.0)
# Requirement already satisfied: super-gradients==3.1.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 194)) (3.1.1)
# Requirement already satisfied: supervision==0.9.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 195)) (0.9.0)
# Requirement already satisfied: svgwrite==1.4.3 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 196)) (1.4.3)
# Requirement already satisfied: sympy==1.12 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 197)) (1.12)
# Requirement already satisfied: tabulate==0.9.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 198)) (0.9.0)
# Requirement already satisfied: tb-nightly==2.14.0a20230615 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 199)) (2.14.0a20230615)
# Requirement already satisfied: tensorboard==2.13.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 200)) (2.13.0)
# Requirement already satisfied: tensorboard-data-server==0.7.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 201)) (0.7.0)
# Requirement already satisfied: termcolor==1.1.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 202)) (1.1.0)
# Requirement already satisfied: terminado in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 203)) (0.17.1)
# Requirement already satisfied: terminaltables==3.1.10 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 204)) (3.1.10)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 205)) (3.1.0)
# Requirement already satisfied: tifffile==2023.4.12 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 206)) (2023.4.12)
# Requirement already satisfied: tinycss2 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 207)) (1.2.1)
# Requirement already satisfied: toml in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 208)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 209)) (2.0.1)
# Requirement already satisfied: torch==1.10.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 210)) (1.10.1)
# Requirement already satisfied: torchmetrics==0.8.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 211)) (0.8.0)
# Requirement already satisfied: torchsummary==1.5.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 212)) (1.5.1)
# Requirement already satisfied: torchvision==0.11.2 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 213)) (0.11.2)
# Requirement already satisfied: tornado in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 214)) (6.2)
# Requirement already satisfied: tqdm==4.65.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 215)) (4.65.0)
# Requirement already satisfied: traitlets in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 216)) (5.7.1)
# Requirement already satisfied: Tree==0.2.4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 217)) (0.2.4)
# Requirement already satisfied: treelib==1.6.1 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 218)) (1.6.1)
# Requirement already satisfied: typing_extensions==4.6.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 219)) (4.6.3)
# Requirement already satisfied: tzdata==2023.3 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 220)) (2023.3)
# Requirement already satisfied: ultralytics==8.0.115 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 221)) (8.0.115)
# Requirement already satisfied: urllib3==1.26.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 222)) (1.26.0)
# Requirement already satisfied: utils==1.0.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 223)) (1.0.1)
# Requirement already satisfied: wcwidth in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 224)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 225)) (0.5.1)
# Requirement already satisfied: websocket-client in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 226)) (0.58.0)
# Requirement already satisfied: websockets==11.0.3 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 227)) (11.0.3)
# Requirement already satisfied: Werkzeug==2.3.6 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 228)) (2.3.6)
# Requirement already satisfied: wget==3.2 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 229)) (3.2)
# Requirement already satisfied: widgetsnbextension in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 230)) (3.5.2)
# Requirement already satisfied: win-inet-pton in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 231)) (1.1.0)
# Requirement already satisfied: wrapt==1.15.0 in c:\users\jense\appdata\roaming\python\python38\site-packages (from -r requirements.txt (line 232)) (1.15.0)
# Requirement already satisfied: yapf==0.40.0 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 233)) (0.40.0)
# Requirement already satisfied: yt-dlp==2023.3.4 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 234)) (2023.3.4)
# Requirement already satisfied: zipp in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from -r requirements.txt (line 235)) (3.11.0)
# Collecting keras>=2.2.4 (from keras-resnet==0.2.0->-r requirements.txt (line 77))
#   Obtaining dependency information for keras>=2.2.4 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Downloading keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pip>=19.3 in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from openmim==0.3.7->-r requirements.txt (line 117)) (23.2.1)
# Requirement already satisfied: setuptools in c:\users\jense\anaconda3\envs\mmyolo\lib\site-packages (from pip-tools==6.13.0->-r requirements.txt (line 126)) (68.0.0)
# Requirement already satisfied: wheel in c:\users\jense\appdata\roaming\python\python38\site-packages (from pip-tools==6.13.0->-r requirements.txt (line 126)) (0.40.0)
# Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 13.5 MB/s eta 0:00:00
# Installing collected packages: keras, mmrotate
#   Attempting uninstall: mmrotate
#     Found existing installation: mmrotate 0.3.4
#     Uninstalling mmrotate-0.3.4:
#       Successfully uninstalled mmrotate-0.3.4
#   Running setup.py develop for mmrotate
# Successfully installed keras-2.13.1 mmrotate
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/open-mmlab/mmrotate.git 'C:\Users\jense\Documents\Python-Rapid\src\mmrotate'
#   Running command git rev-parse -q --verify 'sha^04405ab0f0f0c580cc909df15a162de65a9b668a'
#   Running command git fetch -q https://github.com/open-mmlab/mmrotate.git 04405ab0f0f0c580cc909df15a162de65a9b668a
#   Running command git checkout -q 04405ab0f0f0c580cc909df15a162de65a9b668a

# %%
# import opencv
import cv2 as cv
# import math functions
import math
from math import dist
import numpy as np
# import system libraries
import glob
import os
# import distance calculation libraries
import imutils
from imutils import perspective
# import data processing libraries
import pandas
# import pytorch
import torch
# import socket
from ast import Break
import imp
from multiprocessing.connection import answer_challenge, wait
import socket
import time
# import machine learning model configs
from distutils.version import LooseVersion
import mmcv
from mmcv import Config
from mmdet.datasets import build_dataset
from mmrotate.datasets.builder import ROTATED_DATASETS
from mmrotate.datasets.mvtec import ScrewsDataset
from mmdet.apis import inference_detector, show_result_pyplot, set_random_seed

# %% [markdown]
# ## 2. Define Functions

# %% [markdown]
# #### Miscallaneous Functions

# %%
def check_folder(folder_name): #makes new directory if it does not already exist
    path = os.path.join(os.getcwd(), folder_name)
    print(path)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def clear_images(folder_name, image_start): #removes all specified images from folder
    path = os.path.join(os.getcwd(), folder_name)
    for fname in os.listdir(path):
        if fname.startswith(image_start):
            os.remove(os.path.join(path,fname))

# %% [markdown]
# ## Section 3. Calibrate Camera
# Webcam code reference: https://stackoverflow.com/questions/34588464/python-how-to-capture-image-from-webcam-on-click-using-opencv
# Calibration code reference: https://learnopencv.com/camera-calibration-using-opencv/
# Opencv Calibration doc: https://docs.opencv.org/3.4/dc/dbb/tutorial_py_calibration.html

# %%
def take_webcam_pics(num, folder_name):
    check_folder(folder_name)
    #clear_images(folder_name, "calibration_pic")
    
    webcamVideo = cv.VideoCapture(0)
    cv.namedWindow("webcam") # used to display camera feed
    
    print("press space to save an image")
    while num >= 1:
        ret, frame = webcamVideo.read()
        if not ret: # check if camera is working
            print("Camera off")
            break
            
        cv.imshow("feed", frame) # display camera feed
         
        k = cv.waitKey(1) & 0xFF #gets value of key pressed
        if k == 27: # esc key pressed
            print("Escape hit, closing...")
            break
        elif k == 32: # space key pressed
            image_path = os.path.join(os.getcwd(), folder_name, "calibration_pic_{}.jpg".format(num))
            cv.imwrite(image_path, frame)            
            print("saving image")
            num -= 1
    webcamVideo.release()
    cv.destroyAllWindows()

# %%
def cam_cal(newpics = False): # determine if new cals are needed
    # Defining the dimensions of checkerboard
    CHECKERBOARD = (7,10) # checkerboard needs to be large enough to load
    criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 0.001)
    
    # Creating vector to store vectors of 3D points for each checkerboard image
    objpoints = [] 
    # Creating vector to store vectors of 2D points for each checkerboard image
    imgpoints = [] 

    # Defining the world coordinates for 3D points
    objp = np.zeros((CHECKERBOARD[0] * CHECKERBOARD[1], 3), np.float32)
    objp[:,:2] = np.mgrid[0:CHECKERBOARD[0], 0:CHECKERBOARD[1]].T.reshape(-1, 2)
    prev_img_shape = None

    # Extracting path of individual image stored in a given directory
    if(newpics): #
        take_webcam_pics(20, "calibs") #Take 20 pictures for calibration
    images = glob.glob('./calibs/*.jpg')
    for fname in images:
        img = cv.imread(fname)
        gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
        # Find the chess board corners
        # If desired number of corners are found in the image then ret = true
        ret, corners = cv.findChessboardCorners(gray, CHECKERBOARD, 
            cv.CALIB_CB_ADAPTIVE_THRESH + cv.CALIB_CB_FAST_CHECK + cv.CALIB_CB_NORMALIZE_IMAGE)
        """
        If desired number of corner are detected,
        we refine the pixel coordinates and display them on the images of checker board
        """
        if ret == True:
            objpoints.append(objp)
            # refining pixel coordinates for given 2d points.
            corners2 = cv.cornerSubPix(gray, corners, (11,11),(-1,-1), criteria)
            imgpoints.append(corners2)

            # Draw and display the corners
            #img = cv.drawChessboardCorners(img, CHECKERBOARD, corners2, ret)

        #cv.imshow('img',img) # show images
        #cv.waitKey(0)

    cv.destroyAllWindows()

    h,w = img.shape[:2]

    """
    Performing camera calibration by passing the value of known 3D points (objpoints)
    and corresponding pixel coordinates of the detected corners (imgpoints)
    """
    ret, mtx, dist, rvecs, tvecs = cv.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
    # print calibration values
    """
    print("Camera matrix : \n")
    print(mtx)
    print("dist : \n")
    print(dist)
    print("rvecs : \n")
    print(rvecs)
    print("tvecs : \n")
    print(tvecs)
    """
    return ret, mtx, dist, rvecs, tvecs # return calibration values for future images

# %%
def undistort_img(img, mtx, dist):
    #img = cv.imread(img)
    h, w = img.shape[:2]
    newcameramtx, roi = cv.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))
    
    # undistort
    dst = cv.undistort(img, mtx, dist, None, newcameramtx)
    # crop the image
    x, y, w, h = roi
    dst = dst[y:y+h, x:x+w]
    #cv.imwrite('calibresult.png', dst)
    return dst

# %% [markdown]
# ## 4. Import/Load Pytorch Model

# %%
model = torch.load("screw2.pt") # screw2.pt
#cfg = Config.fromfile('./mmrotate/configs/oriented_rcnn/oriented_rcnn_r50_fpn_1x_dota_le90.py') # for screw.pt
cfg = Config.fromfile('./mmrotate/configs/oriented_rcnn/oriented_rcnn_r50_fpn_fp16_1x_dota_le90.py')  # for screw2.pt

cfg.data['workers_per_gpu']=0

# Modify dataset type and path
cfg.dataset_type = 'ScrewsDataset'
cfg.data_root = 'demo/screwdata/'

cfg.data.test.type = 'ScrewsDataset'
cfg.data.test.data_root = 'demo/screwdata/'
cfg.data.test.ann_file = 'val'
cfg.data.test.img_prefix = 'images'

cfg.data.train.type = 'ScrewsDataset'
cfg.data.train.data_root = 'demo/screwdata/'
cfg.data.train.ann_file = 'train'
cfg.data.train.img_prefix = 'images'

cfg.data.val.type = 'ScrewsDataset'
cfg.data.val.data_root = 'demo/screwdata/'
cfg.data.val.ann_file = 'val'
cfg.data.val.img_prefix = 'images'

# modify num classes of the model in box head
cfg.model.roi_head.bbox_head.num_classes = 13
# We can still use the pre-trained Mask RCNN model though we do not need to
# use the mask branch
#cfg.load_from = 'oriented_rcnn_r50_fpn_1x_dota_le90-6d2b2ce0.pth' # for screw.pt
cfg.load_from = 'oriented_rcnn_r50_fpn_fp16_1x_dota_le90-57c88621.pth' # for screw2.pt

model.cfg = cfg

# Add an attribute for visualization convenience
datasets = [build_dataset(cfg.data.train)]
model.CLASSES = datasets[0].CLASSES

print(model.CLASSES) # check for screws dataset classes

model.eval()
# Out:
# ('long_lag_screw', 'lag_wood_screw', 'wood_screw', 'short_wood_screw', 'shiny_screw', 'black_oxide_screw', 'nut', 'bolt', 'large_nut', 'nut', 'nut', 'machine_screw', 'short_machine_screw')
# OrientedRCNN(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (rpn_head): OrientedRPNHead(
#     (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#     (loss_bbox): SmoothL1Loss()
#     (rpn_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (rpn_cls): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (rpn_reg): Conv2d(256, 18, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
#   (roi_head): OrientedStandardRoIHead(
#     (bbox_roi_extractor): RotatedSingleRoIExtractor(
#       (roi_layers): ModuleList(
#         (0): RoIAlignRotated(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=2, aligned=True, clockwise=True)
#         (1): RoIAlignRotated(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=2, aligned=True, clockwise=True)
#         (2): RoIAlignRotated(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=2, aligned=True, clockwise=True)
#         (3): RoIAlignRotated(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=2, aligned=True, clockwise=True)
#       )
#     )
#     (bbox_head): RotatedShared2FCBBoxHead(
#       (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#       (loss_bbox): SmoothL1Loss()
#       (fc_cls): Linear(in_features=1024, out_features=14, bias=True)
#       (fc_reg): Linear(in_features=1024, out_features=5, bias=True)
#       (shared_convs): ModuleList()
#       (shared_fcs): ModuleList(
#         (0): Linear(in_features=12544, out_features=1024, bias=True)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (cls_convs): ModuleList()
#       (cls_fcs): ModuleList()
#       (reg_convs): ModuleList()
#       (reg_fcs): ModuleList()
#       (relu): ReLU(inplace=True)
#     )
#     init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'layer': 'Linear', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#   )
# )

# %% [markdown]
# extracting bounding box details: https://vinleonardo.com/detecting-objects-in-pictures-and-extracting-their-data-using-mmdetection/

# %%
# Individual Image Testing
#img = mmcv.imread('mmrotate/demo/screwdata/images/screws_210.png')
#model.cfg = cfg
#result = inference_detector(model, img)
#show_result_pyplot(model, img, result, score_thr=0.3)

def parse_bbox(result):
    bbox_result = result
    # if instance segmentation
    # bbox_result, segm_result = result
    labels = [np.full(bbox.shape[0], i, dtype=np.int32) for i, bbox in enumerate(bbox_result)]
    labels = np.concatenate(labels)
    bboxes = np.vstack(bbox_result)
    labels_impt = np.where(bboxes[:, -1] > 0.3)[0]

    classes = model.CLASSES
    labels_impt_list = [labels[i] for i in labels_impt]
    labels_class = [classes[i] for i in labels_impt_list]

    index = 0;
    threshold = -1;
    for i, bbox in enumerate(bboxes[labels_impt]):
        print(i, bbox)
        if bbox[i] > threshold:
            threshold = bbox[i]
            index = i
    if threshold == -1:
        return "null", 0, 0, 0, 0, 0, -1
    lbl = labels_class[i]
    cx = bboxes[labels_impt][i][0]
    cy = bboxes[labels_impt][i][1]
    width = bboxes[labels_impt][i][2]
    height = bboxes[labels_impt][i][3]
    rotation = bboxes[labels_impt][i][4]
    rotation = math.degrees(rotation)
    threshold = bboxes[labels_impt][i][5]
    print(lbl, cx, cy, rotation, threshold)
    return lbl, cx, cy, width, height, rotation, threshold

#print(lbl, cx, cy, width, height, rotation, threshold)
#print(bboxes)

# Extra testing 

#from matplotlib import image
#from matplotlib import pyplot as plt
  
# to read the image stored in the working directory
#data = image.imread('mmrotate/demo/screwdata/images/screws_210.png')
  
#lbl, cx, cy, width, height, rotation, threshold = parse_bbox(result)
#plt.plot(cx, cy, marker='o', color="red")
#plt.plot([cx-width/2, cx+width/2], [cy, cy], color="white", linewidth=2)
#plt.plot([cx, cx], [cy-height/2, cy+height/2], color="white", linewidth=2)
#plt.imshow(data)
#plt.show()

# %% [markdown]
# ## Section 5. Socket Definition

# %% [markdown]
# Socket information https://realpython.com/python-sockets/

# %%
IP = socket.gethostbyname(socket.gethostname())
IP_2 = "127.0.0.1" # Yumi IP address/ 192.168.125.1 (localhost)
print(IP)
# print(IP_2)

PORT = 4455
ADDR = (IP,PORT)
Format = "utf-8"
Size = 1024
# Out:
# 192.168.0.170

# %% [markdown]
# ## Section 6. Main  Function

# %% [markdown]
# Active Calibrated Video Capture with Contouring and Orientation Display

# %%
cal_needed = False
if(os.listdir(".\calibs") == []):
    cal_needed = True
#print(os.listdir(".\calibs"))
ret, mtx, dist, rvecs, tvecs = cam_cal(cal_needed) # calibrate camera

# Start active video capture
webcamVideo = cv.VideoCapture(0)
#cv.namedWindow("webcam") # used to display camera feed

# Socket Info
client_message = "" # Reset client message
print(f"\033[33m[Starting]\033[0m Server is starting.")
server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server.bind(ADDR)
server.listen()

# Main Function 
while client_message != "Stop":
    # Client connected  
    print(f"\033[33m[Listening]\033[0m Server is listening.")
    conn, addr = server.accept() 
    while 1: # with a connection
        server_message = [] # Reset server message
        # Webcam start
        ret, frame = webcamVideo.read()
        undist_frame = undistort_img(frame, mtx, dist) # apply camera calibration
        imgcopy = undist_frame.copy() # copy undistorted image for any processing

        if ret: # if webcam video works
            print("webcam working")
            #cv.imshow("frame", frame) #show distorted frame
            #cv.imshow("undist_feed", imgcopy) # display undistorted camera feed 
        else:
            print('no video')
            webcamVideo.set(cv.CAP_PROP_POS_FRAMES, 0)
            continue
        
        print(f"\033[33m[NEW CONNECTION]\033[0m {addr} connected.")
        client_message = conn.recv(Size).decode(Format) # read message to string
        print("Client Message has been received: ", client_message)
        if not client_message:
            print("message broken")
            break
        if client_message == "Stop":
            break
        if client_message == "Ready" :
            result = inference_detector(model, imgcopy) #Run image detection
            show_result_pyplot(model, imgcopy, result, score_thr=0.3)
            lbl, cx, cy, width, height, theta, threshold = parse_bbox(result)
            server_message = [str(cx), str(cy), str(theta), lbl, "Done"]
            #print(server_message)
            for i in range(len(server_message)):
                temp_str = server_message[i]
                conn.sendto(str.encode(temp_str,Format),addr)
                time.sleep(.25)
            client_message = ""
            time.sleep(5)
        #client_message = conn.recv(Size).decode(Format) # read message to string
        #print("Client Message 2 has been received: ", client_message)    
    conn.close()
print("Program ending")      
print(f"\033[33m[Stopping]\033[0m Server is closing.")
server.close()
webcamVideo.release()
cv.destroyAllWindows()
# Out:
# [Starting] Server is starting.
# [Listening] Server is listening.

# %% [markdown]
# Used for outputting a video or image after running the object detection model

# %%
from mmdet.apis import inference_detector
#import argparse
import mmcv
import cv2
import time

display_type = 1 # image: 0 | webcam: 1

# Build the model.
model = torch.load("screw2.pt")

# Video mode
if display_type == 0:
    cap = mmcv.VideoReader('height_check.mp4') 
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter("testyt.avi", fourcc, cap.fps, (cap.width, cap.height))
    frame_count = 0 # To count total frames.
    total_fps = 0 # To get the final frames per second.

    for frame in mmcv.track_iter_progress(cap):
        # Increment frame count.
        frame_count += 1
        start_time = time.time()# Forward pass start time.
        result = inference_detector(model, frame)
        #print(result)
        end_time = time.time() # Forward pass end time.
        # Get the fps.
        fps = 1 / (end_time - start_time)
        # Add fps to total fps.
        total_fps += fps
        show_result = model.show_result(frame, result, score_thr=0.2)
        # Write the FPS on the current frame.
        cv2.putText(
            show_result, f"{fps:.3f} FPS", (15, 30), cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA
        )
        mmcv.imshow(show_result, 'Result', wait_time=1)
        out.write(show_result)
    # Release VideoCapture()
    out.release()
    # Close all frames and video windows
    cv2.destroyAllWindows()
    # Calculate and print the average FPS
    avg_fps = total_fps / frame_count
    print(f"Average FPS: {avg_fps:.3f}")
else:
    img = cv.imread("images/i4.jpg")
    result = inference_detector(model, img)
    plot = show_result_pyplot(model, img, result, score_thr=0.3)
# Out:
# C:\Users\jense\anaconda3\envs\mmyolo\lib\site-packages\mmdet\models\dense_heads\anchor_head.py:123: UserWarning: DeprecationWarning: anchor_generator is deprecated, please use "prior_generator" instead
#   warnings.warn('DeprecationWarning: anchor_generator is deprecated, '
